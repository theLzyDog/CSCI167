# %% [markdown]
# <a href="https://colab.research.google.com/github/theLzyDog/CSCI167/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-nicst51v
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-nicst51v
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1f962914f754ad5b0af33b0b16efa0544f4a1a19556df3c02dccfcdd18cc3fb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7itu10s9/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# <p>22</p>
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# <p>50</p>
# 3. At what capacity do you expect the maximum of the double descent curve to appear?
# <p>100</p>

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.302054, train error 89.40,  test loss 2.303281, test error 89.47
# Epoch   100, train loss 1.922740, train error 72.62,  test loss 1.772274, test error 70.18
# Epoch   200, train loss 1.910842, train error 72.62,  test loss 1.736309, test error 70.38
# Epoch   300, train loss 1.902720, train error 71.18,  test loss 1.734210, test error 70.55
# Epoch   400, train loss 1.906450, train error 71.82,  test loss 1.726905, test error 69.93
# Epoch   500, train loss 1.903447, train error 71.57,  test loss 1.723739, test error 69.80
# Epoch   600, train loss 1.902977, train error 72.00,  test loss 1.725334, test error 69.95
# Epoch   700, train loss 1.904763, train error 72.40,  test loss 1.740247, test error 69.60
# Epoch   800, train loss 1.902144, train error 72.25,  test loss 1.721323, test error 68.93
# Epoch   900, train loss 1.897718, train error 71.40,  test loss 1.723730, test error 69.18
# Training model with   4 hidden variables
# Epoch     0, train loss 2.300298, train error 88.15,  test loss 2.304485, test error 88.82
# Epoch   100, train loss 1.782062, train error 66.32,  test loss 1.620091, test error 64.30
# Epoch   200, train loss 1.771013, train error 65.05,  test loss 1.618894, test error 63.40
# Epoch   300, train loss 1.767731, train error 65.30,  test loss 1.622480, test error 63.83
# Epoch   400, train loss 1.766480, train error 65.70,  test loss 1.625475, test error 64.00
# Epoch   500, train loss 1.765885, train error 65.65,  test loss 1.630043, test error 64.25
# Epoch   600, train loss 1.763624, train error 65.50,  test loss 1.634380, test error 63.95
# Epoch   700, train loss 1.765036, train error 65.93,  test loss 1.639162, test error 63.90
# Epoch   800, train loss 1.763275, train error 65.88,  test loss 1.637514, test error 64.15
# Epoch   900, train loss 1.761512, train error 65.45,  test loss 1.639173, test error 64.22
# Training model with   6 hidden variables
# Epoch     0, train loss 2.290635, train error 86.43,  test loss 2.285316, test error 86.85
# Epoch   100, train loss 1.647809, train error 57.17,  test loss 1.468124, test error 54.47
# Epoch   200, train loss 1.599477, train error 55.75,  test loss 1.431851, test error 53.62
# Epoch   300, train loss 1.586594, train error 55.65,  test loss 1.440941, test error 54.58
# Epoch   400, train loss 1.580516, train error 55.55,  test loss 1.442987, test error 54.88
# Epoch   500, train loss 1.579144, train error 55.45,  test loss 1.443155, test error 53.83
# Epoch   600, train loss 1.576949, train error 54.97,  test loss 1.434430, test error 53.90
# Epoch   700, train loss 1.571969, train error 55.05,  test loss 1.437242, test error 54.03
# Epoch   800, train loss 1.575048, train error 55.33,  test loss 1.436894, test error 54.22
# Epoch   900, train loss 1.577765, train error 55.40,  test loss 1.432777, test error 54.47
# Training model with   8 hidden variables
# Epoch     0, train loss 2.302791, train error 88.30,  test loss 2.301733, test error 89.10
# Epoch   100, train loss 1.615452, train error 56.90,  test loss 1.429318, test error 55.67
# Epoch   200, train loss 1.571807, train error 55.28,  test loss 1.424209, test error 55.65
# Epoch   300, train loss 1.557210, train error 55.70,  test loss 1.444139, test error 56.20
# Epoch   400, train loss 1.543468, train error 55.92,  test loss 1.449103, test error 56.47
# Epoch   500, train loss 1.536566, train error 55.50,  test loss 1.459577, test error 55.92
# Epoch   600, train loss 1.533030, train error 55.50,  test loss 1.471461, test error 56.45
# Epoch   700, train loss 1.527490, train error 55.17,  test loss 1.467797, test error 56.22
# Epoch   800, train loss 1.526683, train error 55.45,  test loss 1.477405, test error 56.65
# Epoch   900, train loss 1.531360, train error 55.35,  test loss 1.495479, test error 56.35
# Training model with  10 hidden variables
# Epoch     0, train loss 2.277254, train error 85.28,  test loss 2.260782, test error 85.28
# Epoch   100, train loss 1.569594, train error 54.20,  test loss 1.460141, test error 55.97
# Epoch   200, train loss 1.518220, train error 52.83,  test loss 1.462155, test error 55.45
# Epoch   300, train loss 1.504698, train error 53.15,  test loss 1.490647, test error 55.45
# Epoch   400, train loss 1.486013, train error 51.85,  test loss 1.505503, test error 55.75
# Epoch   500, train loss 1.478431, train error 51.20,  test loss 1.511475, test error 54.53
# Epoch   600, train loss 1.467313, train error 50.45,  test loss 1.506938, test error 54.85
# Epoch   700, train loss 1.461773, train error 50.47,  test loss 1.523526, test error 55.62
# Epoch   800, train loss 1.457523, train error 51.00,  test loss 1.532989, test error 55.42
# Epoch   900, train loss 1.458774, train error 50.50,  test loss 1.539175, test error 55.65
# Training model with  14 hidden variables
# Epoch     0, train loss 2.266461, train error 82.95,  test loss 2.262424, test error 83.55
# Epoch   100, train loss 1.395535, train error 45.72,  test loss 1.278859, test error 47.67
# Epoch   200, train loss 1.326009, train error 44.17,  test loss 1.292181, test error 48.50
# Epoch   300, train loss 1.296934, train error 43.40,  test loss 1.300175, test error 48.65
# Epoch   400, train loss 1.286405, train error 43.50,  test loss 1.321364, test error 48.97
# Epoch   500, train loss 1.267378, train error 43.30,  test loss 1.344539, test error 49.40
# Epoch   600, train loss 1.257326, train error 43.35,  test loss 1.371226, test error 49.50
# Epoch   700, train loss 1.249410, train error 42.25,  test loss 1.386413, test error 49.35
# Epoch   800, train loss 1.243947, train error 42.83,  test loss 1.391810, test error 48.90
# Epoch   900, train loss 1.244005, train error 42.58,  test loss 1.404627, test error 50.28
# Training model with  18 hidden variables
# Epoch     0, train loss 2.229902, train error 81.47,  test loss 2.202522, test error 79.60
# Epoch   100, train loss 1.344977, train error 44.10,  test loss 1.251745, test error 46.90
# Epoch   200, train loss 1.254104, train error 41.03,  test loss 1.255129, test error 46.08
# Epoch   300, train loss 1.205279, train error 40.03,  test loss 1.278560, test error 47.38
# Epoch   400, train loss 1.189169, train error 39.25,  test loss 1.319403, test error 48.53
# Epoch   500, train loss 1.160509, train error 38.88,  test loss 1.344230, test error 48.17
# Epoch   600, train loss 1.154801, train error 38.33,  test loss 1.368200, test error 48.47
# Epoch   700, train loss 1.131791, train error 37.70,  test loss 1.387499, test error 49.28
# Epoch   800, train loss 1.130517, train error 38.40,  test loss 1.450713, test error 49.88
# Epoch   900, train loss 1.119321, train error 37.33,  test loss 1.452868, test error 50.30
# Training model with  22 hidden variables
# Epoch     0, train loss 2.192140, train error 81.70,  test loss 2.175633, test error 81.30
# Epoch   100, train loss 1.342872, train error 45.38,  test loss 1.423500, test error 52.92
# Epoch   200, train loss 1.217256, train error 41.05,  test loss 1.461658, test error 51.92
# Epoch   300, train loss 1.168864, train error 39.60,  test loss 1.518565, test error 52.55
# Epoch   400, train loss 1.131946, train error 38.38,  test loss 1.553852, test error 52.90
# Epoch   500, train loss 1.104109, train error 36.60,  test loss 1.590432, test error 52.75
# Epoch   600, train loss 1.085982, train error 36.42,  test loss 1.642943, test error 53.10
# Epoch   700, train loss 1.068803, train error 34.88,  test loss 1.654352, test error 52.70
# Epoch   800, train loss 1.048790, train error 35.03,  test loss 1.719833, test error 53.50
# Epoch   900, train loss 1.035399, train error 34.18,  test loss 1.763519, test error 53.25
# Training model with  26 hidden variables
# Epoch     0, train loss 2.142827, train error 80.75,  test loss 2.096163, test error 80.43
# Epoch   100, train loss 1.216775, train error 40.65,  test loss 1.324343, test error 48.85
# Epoch   200, train loss 1.056656, train error 34.10,  test loss 1.441334, test error 49.03
# Epoch   300, train loss 0.989698, train error 32.32,  test loss 1.582678, test error 51.15
# Epoch   400, train loss 0.926662, train error 30.30,  test loss 1.698981, test error 51.75
# Epoch   500, train loss 0.888826, train error 28.28,  test loss 1.765704, test error 51.70
# Epoch   600, train loss 0.878530, train error 28.93,  test loss 1.850551, test error 52.42
# Epoch   700, train loss 0.849985, train error 27.75,  test loss 1.920427, test error 53.38
# Epoch   800, train loss 0.835381, train error 28.20,  test loss 1.971180, test error 53.53
# Epoch   900, train loss 0.847273, train error 28.03,  test loss 2.069924, test error 53.97
# Training model with  30 hidden variables
# Epoch     0, train loss 2.104991, train error 77.60,  test loss 2.042143, test error 76.80
# Epoch   100, train loss 1.123756, train error 36.40,  test loss 1.302682, test error 47.25
# Epoch   200, train loss 0.972276, train error 31.45,  test loss 1.461582, test error 50.10
# Epoch   300, train loss 0.864064, train error 28.05,  test loss 1.678234, test error 51.45
# Epoch   400, train loss 0.805678, train error 25.97,  test loss 1.863785, test error 52.78
# Epoch   500, train loss 0.764220, train error 24.65,  test loss 2.009004, test error 52.62
# Epoch   600, train loss 0.743897, train error 24.35,  test loss 2.150181, test error 54.20
# Epoch   700, train loss 0.715958, train error 23.57,  test loss 2.249487, test error 54.15
# Epoch   800, train loss 0.708779, train error 23.43,  test loss 2.335164, test error 53.70
# Epoch   900, train loss 0.682294, train error 22.03,  test loss 2.448516, test error 53.62
# Training model with  35 hidden variables
# Epoch     0, train loss 2.208298, train error 81.15,  test loss 2.215979, test error 81.20
# Epoch   100, train loss 1.032784, train error 34.38,  test loss 1.414096, test error 48.75
# Epoch   200, train loss 0.792027, train error 25.62,  test loss 1.684947, test error 50.58
# Epoch   300, train loss 0.679593, train error 22.25,  test loss 2.027649, test error 51.12
# Epoch   400, train loss 0.622140, train error 20.72,  test loss 2.351996, test error 53.35
# Epoch   500, train loss 0.568047, train error 19.20,  test loss 2.647967, test error 53.83
# Epoch   600, train loss 0.530998, train error 18.05,  test loss 2.868428, test error 54.12
# Epoch   700, train loss 0.524314, train error 18.60,  test loss 3.094816, test error 54.35
# Epoch   800, train loss 0.479283, train error 16.15,  test loss 3.368901, test error 56.10
# Epoch   900, train loss 0.466996, train error 16.18,  test loss 3.658288, test error 55.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.087291, train error 77.70,  test loss 2.034216, test error 77.05
# Epoch   100, train loss 0.930264, train error 29.57,  test loss 1.436155, test error 49.67
# Epoch   200, train loss 0.606980, train error 19.12,  test loss 1.958794, test error 53.28
# Epoch   300, train loss 0.504167, train error 16.57,  test loss 2.584669, test error 53.65
# Epoch   400, train loss 0.384209, train error 12.20,  test loss 3.319560, test error 55.00
# Epoch   500, train loss 0.371072, train error 12.78,  test loss 4.096153, test error 57.12
# Epoch   600, train loss 0.275036, train error 8.78,  test loss 4.871456, test error 57.15
# Epoch   700, train loss 0.264180, train error 8.47,  test loss 5.652490, test error 57.62
# Epoch   800, train loss 0.273837, train error 9.38,  test loss 6.163348, test error 57.12
# Epoch   900, train loss 0.307907, train error 11.20,  test loss 6.944745, test error 57.25
# Training model with  45 hidden variables
# Epoch     0, train loss 2.111993, train error 77.70,  test loss 2.093019, test error 78.05
# Epoch   100, train loss 0.794967, train error 25.85,  test loss 1.521619, test error 50.30
# Epoch   200, train loss 0.452820, train error 14.32,  test loss 2.365335, test error 54.00
# Epoch   300, train loss 0.300745, train error 9.10,  test loss 3.427172, test error 54.15
# Epoch   400, train loss 0.202594, train error 6.32,  test loss 4.753613, test error 56.30
# Epoch   500, train loss 0.200017, train error 7.05,  test loss 6.015990, test error 56.50
# Epoch   600, train loss 0.021941, train error 0.03,  test loss 7.332363, test error 56.80
# Epoch   700, train loss 0.011675, train error 0.00,  test loss 8.309072, test error 57.38
# Epoch   800, train loss 0.007869, train error 0.00,  test loss 8.931705, test error 57.33
# Epoch   900, train loss 0.005921, train error 0.00,  test loss 9.433076, test error 57.45
# Training model with  50 hidden variables
# Epoch     0, train loss 2.070342, train error 78.62,  test loss 2.008087, test error 76.15
# Epoch   100, train loss 0.760323, train error 24.03,  test loss 1.561301, test error 50.62
# Epoch   200, train loss 0.356246, train error 9.68,  test loss 2.535137, test error 53.70
# Epoch   300, train loss 0.174171, train error 4.20,  test loss 3.973691, test error 55.17
# Epoch   400, train loss 0.040942, train error 0.07,  test loss 5.552618, test error 55.62
# Epoch   500, train loss 0.016110, train error 0.00,  test loss 6.675009, test error 56.15
# Epoch   600, train loss 0.009838, train error 0.00,  test loss 7.231410, test error 55.88
# Epoch   700, train loss 0.005343, train error 0.00,  test loss 7.771600, test error 55.65
# Epoch   800, train loss 0.003976, train error 0.00,  test loss 8.122951, test error 55.83
# Epoch   900, train loss 0.003173, train error 0.00,  test loss 8.412594, test error 55.92
# Training model with  55 hidden variables
# Epoch     0, train loss 2.055196, train error 76.43,  test loss 1.990744, test error 74.35
# Epoch   100, train loss 0.609884, train error 18.53,  test loss 1.709819, test error 52.25
# Epoch   200, train loss 0.185456, train error 3.88,  test loss 3.127989, test error 53.58
# Epoch   300, train loss 0.032361, train error 0.05,  test loss 4.775151, test error 53.80
# Epoch   400, train loss 0.012665, train error 0.00,  test loss 5.736349, test error 54.55
# Epoch   500, train loss 0.007422, train error 0.00,  test loss 6.317531, test error 54.67
# Epoch   600, train loss 0.005112, train error 0.00,  test loss 6.740982, test error 54.80
# Epoch   700, train loss 0.003852, train error 0.00,  test loss 7.071436, test error 54.75
# Epoch   800, train loss 0.003044, train error 0.00,  test loss 7.342481, test error 54.83
# Epoch   900, train loss 0.002509, train error 0.00,  test loss 7.567216, test error 54.60
# Training model with  60 hidden variables
# Epoch     0, train loss 2.046518, train error 76.50,  test loss 1.989979, test error 76.28
# Epoch   100, train loss 0.523662, train error 15.95,  test loss 1.748281, test error 50.88
# Epoch   200, train loss 0.098658, train error 0.68,  test loss 3.421918, test error 54.85
# Epoch   300, train loss 0.019383, train error 0.00,  test loss 4.766290, test error 54.53
# Epoch   400, train loss 0.009304, train error 0.00,  test loss 5.449432, test error 54.55
# Epoch   500, train loss 0.005888, train error 0.00,  test loss 5.911276, test error 54.42
# Epoch   600, train loss 0.004195, train error 0.00,  test loss 6.247713, test error 54.50
# Epoch   700, train loss 0.003232, train error 0.00,  test loss 6.519855, test error 54.55
# Epoch   800, train loss 0.002604, train error 0.00,  test loss 6.738411, test error 54.55
# Epoch   900, train loss 0.002170, train error 0.00,  test loss 6.931693, test error 54.78
# Training model with  70 hidden variables
# Epoch     0, train loss 2.030229, train error 75.10,  test loss 1.967574, test error 74.38
# Epoch   100, train loss 0.398358, train error 11.18,  test loss 1.845209, test error 50.67
# Epoch   200, train loss 0.036303, train error 0.00,  test loss 3.463701, test error 52.53
# Epoch   300, train loss 0.011645, train error 0.00,  test loss 4.255786, test error 52.45
# Epoch   400, train loss 0.006378, train error 0.00,  test loss 4.713711, test error 52.42
# Epoch   500, train loss 0.004264, train error 0.00,  test loss 5.021794, test error 52.42
# Epoch   600, train loss 0.003152, train error 0.00,  test loss 5.260121, test error 52.55
# Epoch   700, train loss 0.002467, train error 0.00,  test loss 5.448858, test error 52.65
# Epoch   800, train loss 0.002010, train error 0.00,  test loss 5.605522, test error 52.60
# Epoch   900, train loss 0.001689, train error 0.00,  test loss 5.742518, test error 52.60
# Training model with  80 hidden variables
# Epoch     0, train loss 2.003531, train error 74.20,  test loss 1.968220, test error 75.95
# Epoch   100, train loss 0.200210, train error 3.28,  test loss 2.128719, test error 51.53
# Epoch   200, train loss 0.018004, train error 0.00,  test loss 3.385608, test error 52.08
# Epoch   300, train loss 0.007614, train error 0.00,  test loss 3.915004, test error 52.38
# Epoch   400, train loss 0.004572, train error 0.00,  test loss 4.228784, test error 52.42
# Epoch   500, train loss 0.003178, train error 0.00,  test loss 4.458838, test error 52.53
# Epoch   600, train loss 0.002405, train error 0.00,  test loss 4.635653, test error 52.40
# Epoch   700, train loss 0.001913, train error 0.00,  test loss 4.781733, test error 52.35
# Epoch   800, train loss 0.001577, train error 0.00,  test loss 4.901556, test error 52.42
# Epoch   900, train loss 0.001336, train error 0.00,  test loss 5.008259, test error 52.38
# Training model with  90 hidden variables
# Epoch     0, train loss 2.023410, train error 75.65,  test loss 1.968357, test error 74.53
# Epoch   100, train loss 0.136923, train error 1.05,  test loss 2.169004, test error 50.28
# Epoch   200, train loss 0.014248, train error 0.00,  test loss 3.204433, test error 51.00
# Epoch   300, train loss 0.006344, train error 0.00,  test loss 3.628645, test error 51.22
# Epoch   400, train loss 0.003878, train error 0.00,  test loss 3.890789, test error 51.33
# Epoch   500, train loss 0.002725, train error 0.00,  test loss 4.078015, test error 51.55
# Epoch   600, train loss 0.002071, train error 0.00,  test loss 4.227302, test error 51.80
# Epoch   700, train loss 0.001657, train error 0.00,  test loss 4.346928, test error 51.80
# Epoch   800, train loss 0.001370, train error 0.00,  test loss 4.450960, test error 51.85
# Epoch   900, train loss 0.001164, train error 0.00,  test loss 4.539797, test error 51.85
# Training model with 100 hidden variables
# Epoch     0, train loss 1.994028, train error 74.82,  test loss 1.959362, test error 74.32
# Epoch   100, train loss 0.090304, train error 0.10,  test loss 2.329738, test error 51.88
# Epoch   200, train loss 0.012147, train error 0.00,  test loss 3.227946, test error 52.17
# Epoch   300, train loss 0.005619, train error 0.00,  test loss 3.601900, test error 52.72
# Epoch   400, train loss 0.003522, train error 0.00,  test loss 3.839553, test error 52.62
# Epoch   500, train loss 0.002492, train error 0.00,  test loss 4.012084, test error 52.78
# Epoch   600, train loss 0.001908, train error 0.00,  test loss 4.145604, test error 52.80
# Epoch   700, train loss 0.001534, train error 0.00,  test loss 4.257001, test error 52.90
# Epoch   800, train loss 0.001274, train error 0.00,  test loss 4.351096, test error 52.85
# Epoch   900, train loss 0.001085, train error 0.00,  test loss 4.433259, test error 52.78
# Training model with 120 hidden variables
# Epoch     0, train loss 1.990271, train error 74.00,  test loss 1.928508, test error 75.80
# Epoch   100, train loss 0.053721, train error 0.00,  test loss 2.230602, test error 49.83
# Epoch   200, train loss 0.009767, train error 0.00,  test loss 2.884359, test error 50.30
# Epoch   300, train loss 0.004792, train error 0.00,  test loss 3.182546, test error 50.17
# Epoch   400, train loss 0.003054, train error 0.00,  test loss 3.371042, test error 49.97
# Epoch   500, train loss 0.002192, train error 0.00,  test loss 3.507317, test error 49.97
# Epoch   600, train loss 0.001691, train error 0.00,  test loss 3.617992, test error 50.15
# Epoch   700, train loss 0.001366, train error 0.00,  test loss 3.709414, test error 50.05
# Epoch   800, train loss 0.001139, train error 0.00,  test loss 3.786740, test error 49.92
# Epoch   900, train loss 0.000972, train error 0.00,  test loss 3.853151, test error 49.83
# Training model with 140 hidden variables
# Epoch     0, train loss 1.941480, train error 71.82,  test loss 1.869966, test error 73.38
# Epoch   100, train loss 0.035748, train error 0.00,  test loss 2.194552, test error 49.30
# Epoch   200, train loss 0.008020, train error 0.00,  test loss 2.682962, test error 49.22
# Epoch   300, train loss 0.004113, train error 0.00,  test loss 2.917840, test error 49.33
# Epoch   400, train loss 0.002669, train error 0.00,  test loss 3.072070, test error 49.30
# Epoch   500, train loss 0.001940, train error 0.00,  test loss 3.188093, test error 49.47
# Epoch   600, train loss 0.001508, train error 0.00,  test loss 3.279626, test error 49.55
# Epoch   700, train loss 0.001224, train error 0.00,  test loss 3.355202, test error 49.53
# Epoch   800, train loss 0.001024, train error 0.00,  test loss 3.419969, test error 49.60
# Epoch   900, train loss 0.000878, train error 0.00,  test loss 3.476377, test error 49.60
# Training model with 160 hidden variables
# Epoch     0, train loss 1.942282, train error 71.88,  test loss 1.884132, test error 74.00
# Epoch   100, train loss 0.028596, train error 0.00,  test loss 2.126638, test error 50.20
# Epoch   200, train loss 0.007157, train error 0.00,  test loss 2.547869, test error 50.50
# Epoch   300, train loss 0.003756, train error 0.00,  test loss 2.758198, test error 50.67
# Epoch   400, train loss 0.002464, train error 0.00,  test loss 2.895795, test error 50.75
# Epoch   500, train loss 0.001805, train error 0.00,  test loss 2.998686, test error 50.72
# Epoch   600, train loss 0.001410, train error 0.00,  test loss 3.079301, test error 50.62
# Epoch   700, train loss 0.001148, train error 0.00,  test loss 3.148608, test error 50.65
# Epoch   800, train loss 0.000964, train error 0.00,  test loss 3.207302, test error 50.70
# Epoch   900, train loss 0.000828, train error 0.00,  test loss 3.257823, test error 50.78
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926466, train error 70.93,  test loss 1.866760, test error 72.00
# Epoch   100, train loss 0.025046, train error 0.00,  test loss 2.079664, test error 49.17
# Epoch   200, train loss 0.006661, train error 0.00,  test loss 2.442589, test error 48.97
# Epoch   300, train loss 0.003547, train error 0.00,  test loss 2.620459, test error 48.58
# Epoch   400, train loss 0.002343, train error 0.00,  test loss 2.741483, test error 48.55
# Epoch   500, train loss 0.001723, train error 0.00,  test loss 2.831746, test error 48.53
# Epoch   600, train loss 0.001350, train error 0.00,  test loss 2.903578, test error 48.38
# Epoch   700, train loss 0.001102, train error 0.00,  test loss 2.962934, test error 48.30
# Epoch   800, train loss 0.000926, train error 0.00,  test loss 3.013690, test error 48.35
# Epoch   900, train loss 0.000796, train error 0.00,  test loss 3.058267, test error 48.33
# Training model with 200 hidden variables
# Epoch     0, train loss 1.905355, train error 69.45,  test loss 1.845611, test error 72.07
# Epoch   100, train loss 0.020510, train error 0.00,  test loss 1.983596, test error 47.15
# Epoch   200, train loss 0.005922, train error 0.00,  test loss 2.287337, test error 46.70
# Epoch   300, train loss 0.003233, train error 0.00,  test loss 2.446744, test error 46.80
# Epoch   400, train loss 0.002160, train error 0.00,  test loss 2.554875, test error 46.70
# Epoch   500, train loss 0.001596, train error 0.00,  test loss 2.636003, test error 46.83
# Epoch   600, train loss 0.001254, train error 0.00,  test loss 2.701582, test error 46.97
# Epoch   700, train loss 0.001026, train error 0.00,  test loss 2.756469, test error 47.03
# Epoch   800, train loss 0.000865, train error 0.00,  test loss 2.803281, test error 47.00
# Epoch   900, train loss 0.000744, train error 0.00,  test loss 2.844163, test error 47.00
# Training model with 250 hidden variables
# Epoch     0, train loss 1.890131, train error 68.43,  test loss 1.843322, test error 72.32
# Epoch   100, train loss 0.016588, train error 0.00,  test loss 1.945889, test error 47.75
# Epoch   200, train loss 0.005241, train error 0.00,  test loss 2.200005, test error 47.47
# Epoch   300, train loss 0.002929, train error 0.00,  test loss 2.336437, test error 47.47
# Epoch   400, train loss 0.001982, train error 0.00,  test loss 2.429353, test error 47.47
# Epoch   500, train loss 0.001477, train error 0.00,  test loss 2.500554, test error 47.35
# Epoch   600, train loss 0.001167, train error 0.00,  test loss 2.557153, test error 47.35
# Epoch   700, train loss 0.000959, train error 0.00,  test loss 2.605479, test error 47.40
# Epoch   800, train loss 0.000810, train error 0.00,  test loss 2.646830, test error 47.45
# Epoch   900, train loss 0.000699, train error 0.00,  test loss 2.682774, test error 47.42
# Training model with 300 hidden variables
# Epoch     0, train loss 1.882196, train error 69.20,  test loss 1.812226, test error 70.53
# Epoch   100, train loss 0.014475, train error 0.00,  test loss 1.937324, test error 48.05
# Epoch   200, train loss 0.004842, train error 0.00,  test loss 2.172157, test error 48.12
# Epoch   300, train loss 0.002736, train error 0.00,  test loss 2.296450, test error 47.90
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.382576, test error 47.88
# Epoch   500, train loss 0.001393, train error 0.00,  test loss 2.448495, test error 47.88
# Epoch   600, train loss 0.001104, train error 0.00,  test loss 2.501122, test error 47.97
# Epoch   700, train loss 0.000909, train error 0.00,  test loss 2.545270, test error 47.85
# Epoch   800, train loss 0.000769, train error 0.00,  test loss 2.583375, test error 47.90
# Epoch   900, train loss 0.000664, train error 0.00,  test loss 2.617340, test error 47.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.868997, train error 67.28,  test loss 1.798314, test error 70.07
# Epoch   100, train loss 0.011763, train error 0.00,  test loss 1.785542, test error 45.92
# Epoch   200, train loss 0.004189, train error 0.00,  test loss 1.962443, test error 45.70
# Epoch   300, train loss 0.002427, train error 0.00,  test loss 2.061901, test error 45.70
# Epoch   400, train loss 0.001672, train error 0.00,  test loss 2.130374, test error 45.60
# Epoch   500, train loss 0.001260, train error 0.00,  test loss 2.183833, test error 45.45
# Epoch   600, train loss 0.001003, train error 0.00,  test loss 2.227226, test error 45.47
# Epoch   700, train loss 0.000829, train error 0.00,  test loss 2.262968, test error 45.35
# Epoch   800, train loss 0.000704, train error 0.00,  test loss 2.294546, test error 45.28
# Epoch   900, train loss 0.000609, train error 0.00,  test loss 2.321988, test error 45.17

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
